# %%
Enes Batuhan Ay
9.1

# %%
import numpy as np
import scipy.linalg as sl
n = 200
m = 500
a = np.random.normal(0, 1, (n,m))
c = np.random.rand(m)
r = np.random.rand(m)
b = sl.toeplitz(c,r)
print("a")
print(A)
print("b")
print(B)
# Out:
# a
# [[ 1.55499226  0.29491518  0.84604738 ...  0.30207214  0.08670942
#    1.17516002]
#  [ 1.21538627  0.56396638 -2.07180131 ...  0.1565291   0.38100068
#    0.83614528]
#  [ 0.53827882  0.10572124 -0.65582345 ...  0.3750748   0.3658541
#    0.18989164]
#  ...
#  [-0.84398713 -0.25921674 -0.99235921 ...  1.507004   -0.02638622
#    1.31320867]
#  [ 0.24909592  1.89632595 -0.39378771 ...  0.4531631   0.28082444
#    0.01626145]
#  [-0.77192284 -0.19066613 -0.01772752 ... -0.01094802  0.12590941
#   -0.9625274 ]]
# b
# [[0.33576579 0.4335153  0.26380824 ... 0.9017396  0.4688095  0.24864023]
#  [0.25520701 0.33576579 0.4335153  ... 0.91513617 0.9017396  0.4688095 ]
#  [0.25880123 0.25520701 0.33576579 ... 0.34351927 0.91513617 0.9017396 ]
#  ...
#  [0.59646964 0.82989946 0.70197593 ... 0.33576579 0.4335153  0.26380824]
#  [0.44612696 0.59646964 0.82989946 ... 0.25520701 0.33576579 0.4335153 ]
#  [0.12134878 0.44612696 0.59646964 ... 0.25880123 0.25520701 0.33576579]]

# %%
9.2

# %%
print(a+a)
print(np.dot(a, a.T))


def function(a, b, Lambda):
    c = b - Lambda * (np.eye(m))
    d = np.dot(a,c)
    return d
print("A(B - λI): ")
print(func1(a, b, 3))
# Out:
# [[ 4.63045525  0.85370658 -1.95312809 ... -1.47667397 -1.15959883
#   -1.52800969]
#  [-0.81863681 -1.87129178  0.26130981 ... -0.41712525 -1.31885591
#   -4.46376395]
#  [ 2.31469498 -0.65539593 -1.24961879 ... -2.15377057 -3.46281848
#   -0.51558616]
#  ...
#  [-2.99900687  1.49054711 -2.17160713 ... -5.32708798 -3.01957059
#    1.0936024 ]
#  [ 0.22010469  1.15400154 -2.15884866 ...  0.83152322  3.06234491
#   -0.51352501]
#  [ 1.56525687  1.53216201  0.8851098  ...  3.4894068   1.99358579
#    0.18995097]]
# [[516.09289998 -13.02591484  22.71868053 ...  15.73934737   5.54817797
#    13.87194367]
#  [-13.02591484 497.49615969  20.50783993 ...  -9.95006421  -5.86837596
#    56.99249807]
#  [ 22.71868053  20.50783993 496.09791749 ... -30.08061685  30.05394884
#    -4.80289056]
#  ...
#  [ 15.73934737  -9.95006421 -30.08061685 ... 466.77463334 -26.15899791
#   -55.4708797 ]
#  [  5.54817797  -5.86837596  30.05394884 ... -26.15899791 474.68152154
#    -2.05083084]
#  [ 13.87194367  56.99249807  -4.80289056 ... -55.4708797   -2.05083084
#   523.39734628]]
# A(B - λI):
# [[-33.82597868 -23.98998003 -15.67155421 ... -24.02315134 -24.41683612
#   -17.05612233]
#  [ -1.84693456   6.46972297  -3.72083152 ...  -1.44296613   2.77284077
#     2.55720111]
#  [ -7.92893149 -10.07908157 -21.32568198 ... -12.59335798  -2.44258073
#   -15.20269357]
#  ...
#  [  3.38553922  -5.62869327  -3.8881546  ...   0.82962309   3.35033673
#    -5.62651616]
#  [-17.02607833 -19.73828682 -28.03373837 ... -21.57499935 -35.19729104
#   -21.81825097]
#  [  4.23240685   2.22733797   0.45182343 ...  16.99019707   1.98743149
#    14.29204162]]

# %%
9.3

# %%
print(np.linalg.norm(A, "fro"))
print(np.linalg.norm(B, np.inf))
print("largest  value of b")
print(np.linalg.norm(B, 2))
print("smallest value of b")
print(np.linalg.norm(B, -2))
# Out:
# 317.1635034819457
# 254.92006624776826
# largest  value of b
# 250.59103802220963
# smallest value of b
# 0.17278676463700873

# %%
9.4

# %%
Z = np.random.normal(3,1, (n, n))
a, b = np.linalg.eig(Z)
print("largest eigenvalue: ")
print(a.max())
# Out:
# largest eigenvalue:
# (599.1520148054896+0j)
